# %%
import numpy as np
from imageio import imread
from sklearn.model_selection import train_test_split
from IPython.display import display
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
from numpy.random import normal, uniform
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from sklearn.utils import resample
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.linear_model import Ridge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler


def create_X(x, y, n ):
    L = ['1']
    if len(x.shape) > 1:
        x = np.ravel(x)
        y = np.ravel(y)

    N = len(x)
    l = int((n+1)*(n+2)/2) # Number of elements in beta
    X = np.ones((N,l))

    for i in range(1,n+1):
        q = int((i)*(i+1)/2)
        for k in range(i+1):
            X[:,q+k] = (x**(i-k))*(y**k)
            if (i == 0 and k == 0) :
                L.append('1')
            elif(i-k == 0):
                L.append('Y^' + str(k))
            elif (k == 0):
                L.append('X^' + str(i-k))
            elif (i==2 and k == 1):
                L.append('XY')
            elif(i-k == 1):
                L.append('X'+'Y^' + str(k))
            elif (k == 1):
                L.append('X^' + str(i-k)+'Y')
            else :
                L.append('X^' + str(i-k)+'Y^'+ str(k))
    return X, L

def R2(y_data, y_model):
    return 1 - np.sum((y_data - y_model) ** 2) / np.sum((y_data - np.mean(y_data)) ** 2)

def MSE(y_data,y_model):
    n = np.size(y_model)
    return np.sum((y_data-y_model)**2)/n

def FrankeFunctionWithNoise(x,y):
    term1 = 0.75*np.exp(-(0.25*(9*x-2)**2) - 0.25*((9*y-2)**2))
    term2 = 0.75*np.exp(-((9*x+1)**2)/49.0 - 0.1*(9*y+1))
    term3 = 0.5*np.exp(-(9*x-7)**2/4.0 - 0.25*((9*y-3)**2))
    term4 = -0.2*np.exp(-(9*x-4)**2 - (9*y-7)**2)
    noise = np.random.normal(0, 0.1, len(x)*len(x))
    noise = noise.reshape(len(x),len(x))
    return term1 + term2 + term3 + term4 + noise

def predict(beta, X):
    return X @ beta


def plotFunction(x, y, z, title):
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    # Plot the surface
    surf = ax.plot_surface(x, y, z, cmap=cm.coolwarm,linewidth=0, antialiased=False)
    # Customize the z axis.
    ax.zaxis.set_major_locator(LinearLocator(10))
    ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
    # Add a color bar which maps values to colors.
    fig.suptitle(title)
    fig.colorbar(surf, shrink=0.5, aspect=5)

    
def gradientOLS(N, x, y, theta):
    return (2.0/N)*x.T @ (x @ theta-y)

def gradientsRidge(N, lmbda, X, y, theta):
    return 2.0/N*X.T @ (X @ (theta)-y)+2*lmbda*theta

# %%
def SDG(X, y, n_batches, n_epochs, learning_rate, M):
    
    theta = np.random.randn(X.shape[1])

    for epoch in range(n_epochs):
    
        np.random.shuffle(X)
        np.random.shuffle(y)
        
        for i in range(n_batches):
            
            random_index = np.random.randint(n_batches)
            xi = X[random_index:(random_index+1)]
            yi = y[random_index:(random_index+1)]
            gradient = gradientOLS(M, xi, yi, theta)
            theta = theta - learning_rate*gradient
  
    return theta

# %%
def adagradSDG(X, y, n_epochs, n_batches, M, learning_rate):
    delta = 1e-7
    theta = np.random.randn(X.shape[1])
    r = [0.0 for _ in range(X.shape[1])]
    for epoch in range(n_epochs):
        for i in range(n_batches):
            random_index = np.random.randint(n_batches)
            xi = X[random_index:(random_index+1)]
            yi = y[(random_index):(random_index+1)]
            gradients = gradientOLS(M, xi, yi, theta)
            for j in range(gradients.shape[0]):
                r[j] = r[j] + gradients[j]**2.0
                alpha = eta / (delta + np.sqrt(r[j]))
                theta[j] = theta[j] - alpha * gradients[j]
    return theta

# %%
def adamSDG(X, y, n_epochs, n_batches, M, learning_rate):
    
    beta_1 = 0.9
    beta_2 = 0.999
    epsi = 1e-7
    
    
    theta = np.random.randn(X.shape[1])
    m = [0.0 for _ in range(X.shape[1])]
    s = [0.0 for _ in range(X.shape[1])]
    for epoch in range(n_epochs):
        for i in range(n_batches):
            random_index = np.random.randint(n_batches)
            xi = X[random_index*M:(random_index+1)*M]
            yi = y[(random_index)*M:(random_index+1)*M]
            gradients = gradientOLS(M, xi, yi, theta)                
            for j in range(1, gradients.shape[0]):
                m[j] = beta_1*m[j] + (1-beta_1)*gradient[j]
                s[j] = beta_2*s[j] + (1-beta_2)*(gradient[j]**2)
                m[j] = m[j]/(1-beta_1**j)
                s[j] = s[j]/(1-beta_2**j)
                theta[j] = theta[j] -learning_rate*(m[j]/(np.sqrt(s[j])-epsi))
    return theta

# %%
#################    DATA     ################
################# Parameters #################

poly = 7
N = 100 #number of data

##############################################

#terrain = imread('SRTM_data_Norway_2.tif')
#terrain = terrain[:N, :N]
#Creates mesh of image pixels
#x = np.linspace(0,1, np.shape(terrain)[0])
#y = np.linspace(0,1, np.shape(terrain)[1])
#z = terrain
#x_mesh, y_mesh = np.meshgrid(x,y)


x = np.linspace(0, 1, N)
y = np.linspace(0, 1, N)
x_mesh, y_mesh = np.meshgrid(x,y)
z = FrankeFunctionWithNoise(x_mesh, y_mesh)


x_y = np.empty((len(x)*len(x), 2))
x_y[:, 0] = x_mesh.ravel()
x_y[:, 1] = y_mesh.ravel()

scaler = StandardScaler()
scaler.fit(x_y)
x_y = scaler.transform(x_y)
x_y_train, x_y_test, z_train, z_test = train_test_split(x_y, z.ravel(), test_size=0.2)

X_train, coeff = create_X(x_y_train[:, 0], x_y_train[:, 1], poly )
X_test, coeff = create_X(x_y_test[:, 0], x_y_test[:, 1], poly )
X , coeff = create_X(x_y[:, 0], x_y[:, 1], poly)

# %%
################### linalg  OLS #################
beta_linreg = np.linalg.pinv(X_train.T.dot(X_train)).dot(X_train.T).dot(z_train)
print("beta from linalg")
print(beta_linreg)
ztildeLinreg = X_train @ beta_linreg
ztestLinreg = X_test @ beta_linreg
MSE_train_linreg = np.mean((z_train - ztildeLinreg)**2, keepdims=True )
MSE_test_linreg = np.mean((z_test - ztestLinreg)**2, keepdims=True )
print("MSE_train")
print(MSE_train_linreg)
print("MSE_test")
print(MSE_test_linreg)
print("\n")
print("-----------------------------")
print("\n")
plotFunction(x_mesh, y_mesh, z, "Plot of our data")
plotFunction(x_mesh, y_mesh, (X @ beta_linreg).reshape(len(x), len(x)), "Plot of regression with linreg")
plt.show()
# Out:
# beta from linalg
# [ 0.30937566 -0.00088425 -0.42282177  0.41066096  0.19618558  0.11493812
#  -0.134281   -0.28130074 -0.33411701  0.2160351  -0.27366927 -0.09399905
#  -0.0141207   0.00976951 -0.10712682  0.07469574  0.17346168  0.08842421
#   0.0565065   0.13657792 -0.03117518  0.04548613  0.00974883  0.01479185
#   0.01498656 -0.01022585 -0.01420853  0.02237014 -0.01333472 -0.01877879
#  -0.00473507 -0.0315852  -0.01979356  0.00326934 -0.0156635  -0.00118133]
# MSE_train
# [0.0104797]
# MSE_test
# [0.01107189]
#
#
# -----------------------------

# %%
################### DG OLS ##################

Niterations = 100000

############################################
# Hessian matrix
H = (2.0/N)* X_train.T @ X_train
# Get the eigenvalues
EigValues, EigVectors = np.linalg.eig(H)
beta = np.random.randn(X_train.shape[1])
eta = 1.0/np.max(EigValues)
for iter in range(Niterations):
    gradient = gradientOLS(N, X_train, z_train, beta)
    beta -= eta*gradient
print("beta from own dg")
print(beta)
ztildeDG = X_train @ beta
ztestDG = X_test @ beta
MSE_train_dg = np.mean((z_train - ztildeDG)**2, keepdims=True )
MSE_test_dg = np.mean((z_test - ztestDG)**2, keepdims=True )
print("MSE_train")
print(MSE_train_dg)
print("MSE_test")
print(MSE_test_dg)
print("\n")
print("-----------------------------")
print("\n")
plotFunction(x_mesh, y_mesh, z, "Plot of our data")
plotFunction(x_mesh, y_mesh, (X @ beta).reshape(len(x), len(x)), "Plot of regression with DG")
plt.show()
# Out:
# beta from own dg
# [ 0.2596764  -0.09660167 -0.35127014  0.50855165  0.1743884   0.26734102
#   0.08311457 -0.26354909 -0.29743264  0.02507061 -0.34007775 -0.08255785
#  -0.06773189  0.02547363 -0.22143738 -0.05948968  0.14952202  0.05052807
#   0.07108624  0.12940001  0.09300824  0.05876219  0.00799665  0.02322212
#   0.01216904  0.00098675 -0.01721327  0.04609619  0.01126758 -0.01404773
#   0.00405781 -0.02954816 -0.01717458 -0.00248741 -0.01503238 -0.02456182]
# MSE_train
# [0.01108395]
# MSE_test
# [0.01165125]
#
#
# -----------------------------

# %%
################### SDG OLS ##################
############## With Classique SDG ############

nbEta = 20
Eta = np.logspace(-5, -3, nbEta)
M = 1  #size of each minibatch
n_batches = int(N/M) #number of minibatches
n_epochs = 1000 #number of epochs

#############################################
best_eta = Eta[0]
best_mse = 1e10
MSE_train = [0]
MSE_test = [0]
i = 0
new_eta = []
while i < len(Eta) and MSE_train[-1] < 1e15:
    beta = SDG(X_train, z_train, n_batches, n_epochs, Eta[i], M = M)
    print("beta from own sdg")
    print("for learning_rate = ", Eta[i])
    print(beta)
    ztildeSDG = predict(beta, X_train)
    ztestSDG = predict(beta, X_test)
    MSE_train_sdg = np.mean((z_train - ztildeSDG)**2, keepdims=True )
    MSE_test_sdg = np.mean((z_test - ztestSDG)**2, keepdims=True )
    MSE_train.append(MSE_train_sdg)
    MSE_test.append(MSE_test_sdg)
    print("MSE_train")
    print(MSE_train_sdg)
    print("MSE_test")
    print(MSE_test_sdg)
    print("\n")
    print("-----------------------------")
    print("\n")
    new_eta.append(Eta[i])
    if MSE_test_sdg < best_mse:
        best_eta = Eta[i]
        best_mse = MSE_test_sdg
        zpred = predict(beta, X)
    i +=1

plt.plot(new_eta[:-1], MSE_train[1:-1], label = "MSE_train")
plt.plot(new_eta[:-1], MSE_test[1:-1], label = "MSE_test")
plt.xscale('log')
plt.xlabel('learning_rate')
plt.ylabel('MSE')
plt.title("SDG OLS")
plt.legend()

plotFunction(x_mesh, y_mesh, z, "Plot of our data")
title = "plot of regression with SDG with learning rate =" + str(best_eta)
plotFunction(x_mesh, y_mesh, zpred.reshape(len(x), len(x)),title)


plt.show()
# Out:
# beta from own sdg
# for learning_rate =  1e-05
# [ 0.46196252 -0.15198663  0.44228322  0.64132348 -0.74595018 -0.07025645
#  -0.48694813 -0.17903448  0.89876391 -0.30723261 -0.98805365 -0.69083123
#  -0.83282112  1.63672167  0.90429322  0.57894004 -1.32216001 -1.01011089
#   1.35773104  0.20384882 -0.00197993  0.32052408  0.30028766 -0.1044688
#  -0.234429    0.42739133 -0.3706464  -0.36735816 -0.15309504  0.36545139
#   0.30926204 -0.01861434 -0.07230186 -0.35664635 -0.07059576  0.01464733]
# MSE_train
# [0.67898872]
# MSE_test
# [0.64610016]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  1.2742749857031348e-05
# [ 0.92056657  0.79321987 -0.0958238  -0.39087789 -1.28116111 -1.1475053
#  -0.10673691  1.50667742 -0.72090372  1.18968827 -0.01318693  1.11637561
#   0.55932314  0.35670622  0.24797486  0.01878209 -0.66320419 -1.09086615
#  -0.98739514  0.98098859 -1.09844896  0.04798783 -0.15635349 -0.13248792
#  -0.32406698 -0.06264727  0.05268973  0.03792204 -0.03184816 -0.14458846
#   0.3894557   0.84380682 -0.0034938  -0.28362192 -0.21625568  0.29525577]
# MSE_train
# [0.68538054]
# MSE_test
# [0.80829435]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  1.623776739188721e-05
# [ 0.47153744 -1.43587982 -0.70569314 -1.23706709  1.48093218  0.26477863
#   0.692843   -0.07065972  0.46244606 -0.00370227  0.99285065 -1.51456826
#   0.86265785 -0.79487661 -0.48477305 -0.08590119  1.03469531  0.62053043
#   0.12135595  0.26628026  0.12492    -0.19010553  0.39409336 -0.29155929
#   0.1311468  -0.05232681  0.1785333   0.11868972  0.03400681 -0.3890199
#  -0.48972657  0.16597875  0.27150721 -0.24328703 -0.23151617  0.01413343]
# MSE_train
# [0.65286211]
# MSE_test
# [0.72738033]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  2.06913808111479e-05
# [ 0.01350184 -0.18732852 -0.23685421 -0.61434228 -0.72696793  1.62593978
#   0.31300373  0.85113126  1.25003671  0.45949182  1.00006188 -0.3045247
#  -0.52489813  0.12364908 -1.13907266 -0.59107412 -0.34773391  0.02887859
#  -0.67935563 -0.64426187 -0.24179575 -0.27017668  0.3212845   0.06526224
#  -0.33620599  0.11239426  0.20662987  0.22699548  0.20167933  0.05178249
#  -0.25351511  0.05555117  0.29998806  0.16583201 -0.01469568  0.04185793]
# MSE_train
# [0.38547848]
# MSE_test
# [0.46763981]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  2.6366508987303556e-05
# [ 0.02261508  0.27555623  0.42115151 -0.88337135 -0.46491415  1.63052873
#   0.2511267   0.78820712 -1.14047919 -1.13646234  1.15345743 -0.00258854
#  -0.06215157 -0.17643352 -1.34051269 -0.41080181 -0.28834677  0.52039427
#  -0.04335484  0.62413182  0.51183386 -0.29706952  0.17116431 -0.02903695
#  -0.25082018  0.00949063  0.21894077  0.29434709  0.10090278 -0.06172118
#  -0.04370401  0.2641637  -0.13751644 -0.19537976 -0.09318124 -0.03565293]
# MSE_train
# [0.30245067]
# MSE_test
# [0.36723482]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  3.359818286283781e-05
# [ 0.70353962  0.44065124  0.6268766   0.7558723  -0.70894185  0.11382289
#  -0.31918224 -0.1448028   0.95567207  0.73309247 -0.88221283  0.60497253
#  -0.24331553  0.45847585 -0.58277698  0.06835789  0.34680042 -0.45859927
#  -0.33904017 -0.91230425 -1.19115936  0.20045734 -0.16785599  0.18590321
#  -0.02941729 -0.04034454 -0.11687546  0.20388531  0.00557531 -0.15619464
#   0.11643669  0.16636626  0.0818494   0.01184125  0.20759548  0.32935747]
# MSE_train
# [0.43142518]
# MSE_test
# [0.55583074]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  4.281332398719396e-05
# [ 0.3117344  -0.42879242  0.35094974  0.83845781  1.15722808  0.2550464
#  -0.25846908  0.21401025  0.40138635  0.72248025 -1.3150601  -2.01034829
#   1.20175965  0.56830285 -0.70441268  0.56503165 -0.40944083  0.12826992
#  -0.3645688  -0.52819086 -0.80202034  0.3655343   0.50722463 -0.23698086
#   0.17925977 -0.2098159  -0.25397271  0.21475722 -0.16616153  0.12332869
#   0.04254241 -0.05058476 -0.11516304  0.16611742  0.19229891  0.17286224]
# MSE_train
# [0.52002172]
# MSE_test
# [0.49703094]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  5.4555947811685143e-05
# [ 0.06958067 -0.46961654 -0.76687385  0.35934994  0.23235117  0.8218337
#   1.53943726 -0.52319402  0.48368632  0.17665098 -0.19165051 -0.28041049
#  -0.16522423 -0.04244057 -0.51520762 -1.15490688  0.58402865 -0.15438407
#   0.14262749 -0.41996771  0.46130842  0.03394012  0.0775934  -0.01060778
#   0.0286747   0.05216108  0.01328507  0.08666458  0.22743044 -0.08975191
#   0.03565992 -0.12040693  0.02192415  0.00915416  0.08343816 -0.15971756]
# MSE_train
# [0.24661601]
# MSE_test
# [0.16044542]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  6.951927961775606e-05
# [ 0.33518686  0.38304113 -0.45969727 -0.53531693  0.22352813  0.94161162
#  -0.42954157  1.20803753 -1.07564942  0.66690574  0.38018415 -0.23897733
#   6.30796606e+22 -8.62320517e+21  1.20011050e+22 -4.38752457e+22
#  -1.34596488e+22 -3.92927794e+21  3.87389667e+21  2.09701137e+22
#   6.60070675e+22 -1.25746667e+22 -6.37328905e+21  1.54825872e+21
#  -1.36634136e+22 -3.04977286e+22 -1.40124167e+22 -2.17345696e+21
#   4.82786232e+22 -7.12364750e+21  5.39112953e+21  4.76422172e+21]
# MSE_train
# [2.58549168e+46]
# MSE_test
# [2.75847644e+46]
#
#
# -----------------------------

# %%
################### SDG OLS ##################
############## With Adagrad ##################

nbEta = 40
Eta = np.logspace(-9, -1, nbEta)
M = 2  #size of each minibatch
n_batches = int(N/M) #number of minibatches
n_epochs = 500 #number of epochs

#############################################
best_eta = Eta[0]
best_mse = 1e10
MSE_train = [0]
MSE_test = [0]
i = 0
new_eta = []
while i < len(Eta) and MSE_train[-1] < 1e15:
    beta = adagradSDG(X_train, z_train, n_epochs, n_batches, M, Eta[i])
    print("beta from own sdg")
    print("for learning_rate = ", Eta[i])
    print(beta)
    ztildeSDG = predict(beta, X_train)
    ztestSDG = predict(beta, X_test)
    MSE_train_sdg = np.mean((z_train - ztildeSDG)**2, keepdims=True )
    MSE_test_sdg = np.mean((z_test - ztestSDG)**2, keepdims=True )
    MSE_train.append(MSE_train_sdg)
    MSE_test.append(MSE_test_sdg)
    print("MSE_train")
    print(MSE_train_sdg)
    print("MSE_test")
    print(MSE_test_sdg)
    print("\n")
    print("-----------------------------")
    print("\n")
    new_eta.append(Eta[i])
    if MSE_train_sdg < best_mse:
        best_eta = Eta[i]
        best_mse = MSE_train_sdg
        zpred = predict(beta, X)
    i +=1

plt.plot(new_eta[:-1], MSE_train[1:-1], label = "MSE_train")
plt.plot(new_eta[:-1], MSE_test[1:-1], label = "MSE_test")
plt.xscale('log')
plt.xlabel('learning_rate')
plt.ylabel('MSE')
plt.title("SDG OLS")
plt.legend()

plotFunction(x_mesh, y_mesh, z, "Plot of our data")
title = "plot of regression with SDG with learning rate =" + str(best_eta)
plotFunction(x_mesh, y_mesh, zpred.reshape(len(x), len(x)),title)

plt.show()
# Out:
# beta from own sdg
# for learning_rate =  1e-09
# [ 1.59360193 -0.50540189 -0.63117318 -1.42780587  0.29648277  0.43694246
#   0.12784206  0.57121274  0.33529435  0.09112857 -1.8448924  -1.20820376
#   0.37403772  0.71395532 -0.24606943  0.33796926 -0.12053288 -0.46970137
#  -1.02798378 -0.91306932  0.85005633  0.91510433  0.30351823 -0.25273017
#  -0.02849143  0.34556482 -0.00814644 -0.18475067 -0.10674359 -0.11559525
#   0.15135473  0.53989793 -0.44507155 -0.0865875   0.70913777 -0.33625841]
# MSE_train
# [5.93516014]
# MSE_test
# [5.55098788]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  1.6037187437513277e-09
# [ 0.22793175  0.58948838  1.78643432 -0.55181125 -1.1036888   0.3518017
#   0.72477845 -0.01102463 -0.55253388 -0.06526854 -0.6406626   0.54771827
#   0.15399079  0.60443571  1.75631157  0.45607737 -1.19632033 -0.65443121
#  -0.63013964 -1.47937629 -1.49608422  0.28009357  0.2070479   0.80742705
#  -0.86424568 -1.29272947  0.12358416 -0.56132459 -0.29827157  0.34616682
#  -0.18482624  0.25123469  0.73950983  0.32425664  0.55425373  0.47600739]
# MSE_train
# [11.05359525]
# MSE_test
# [10.81167254]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  2.571913809059347e-09
# [ 0.59898138  0.08340259 -1.06283636  0.951113   -0.42586325  0.42355506
#   0.45926757  0.96529335 -1.23769994 -0.20970932  0.30255138 -0.05493414
#  -0.16513425  0.47306764 -0.30350633  0.30274702  0.91498736  0.09208869
#   1.41428958 -1.54055396  0.49879598 -0.23954828 -0.02451391 -0.26879617
#   0.95981344  0.04480505 -1.02407636  0.29897724 -0.21879754 -0.54580017
#   0.70469956 -0.20866591 -0.26897983 -0.45737855  0.37971177  0.02633936]
# MSE_train
# [16.29171763]
# MSE_test
# [15.95531085]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  4.124626382901348e-09
# [ 0.34730658  0.63884304 -0.12951357  0.24146763  0.61185702 -0.16947737
#  -0.2760773   0.82166374  0.82855777 -1.45495875 -0.13732267  0.24652728
#  -0.30742734 -0.52179653  0.74196941 -0.28680754  1.24461409 -0.26792657
#   0.97338355 -0.10547847 -0.37095695 -0.24765259 -0.05264399  1.52528575
#   0.34328621 -1.18296489 -0.18868491 -0.13128216 -0.01923469 -0.47343645
#   0.60705454 -0.42159046 -0.69336666 -0.23591066  0.15573468  0.37484986]
# MSE_train
# [6.25786446]
# MSE_test
# [6.05854788]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  6.614740641230159e-09
# [ 0.83665094  0.10333104  0.14770676 -0.45464057 -2.45479029  0.48070554
#   0.93480059  0.46313278  0.14115722  1.89283933 -0.97026738  0.73959956
#  -0.40133861  0.18129234 -0.37345871 -0.40848927 -0.1178746  -0.92055221
#  -0.2934714  -0.71229538 -1.26083578  0.45858139  0.08037668  0.17375019
#  -0.03086621 -0.05932243  0.19430399  0.20876232  0.06130869 -0.39312811
#   0.04706386  1.13776086  0.30754631 -0.88085385  0.13162432  0.32103189]
# MSE_train
# [4.98479286]
# MSE_test
# [4.96581331]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  1.0608183551394482e-08
# [ 0.00417034 -2.11266264  0.24925194 -0.84948834  0.53083272  1.50262402
#   1.18655643  0.47959095  1.44026569  0.09762121 -0.64796867 -1.27919145
#  -0.26751207  0.03884324 -0.23338642 -0.22962113 -0.78581357 -0.07320101
#  -0.30551638  0.39573899 -0.1639841   0.43536153  0.24976099 -0.12253296
#   0.84555691  0.29014099 -0.51808468 -0.04909349  0.04612604  0.40935626
#  -0.50462473 -0.86804895  0.43104179  0.75575641 -0.40352492  0.01005518]
# MSE_train
# [4.49630451]
# MSE_test
# [4.30392456]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  1.7012542798525893e-08
# [ 0.36500452 -0.83239139 -0.8846048  -0.70499202 -0.00357753  1.25044173
#   0.10707058  1.12433439  1.00407352  2.19438062 -1.50996442  2.05609871
#   0.80827404  0.1155419   1.66876064 -0.53453255  0.10700657 -0.10091906
#   0.33355019 -0.33925657 -0.77927239 -0.14418696 -0.63752759  0.83774779
#  -0.98787628 -0.94167986  0.65544104  0.58447904 -0.44576236 -0.47993547]
# MSE_train
# [7.3807813]
# MSE_test
# [7.69204936]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  2.0309176209047348e-05
# [-0.670482    0.43519748 -0.90581098  0.19722021  0.03615812  2.24298695
#  -1.49731468 -0.25287752 -0.20848986  0.97340699  0.41457805 -0.44662553
#  -0.92889342 -0.15203733 -0.45020106  0.08768602 -0.05382178  0.6318451
#   0.46336213 -0.46728854  1.43098708 -0.15249402  0.04751361  0.05122491
#   0.83388997  0.01221742 -0.60236801  0.15915929  0.17553944  0.18873768
#  -0.23973758 -1.10339928  0.34407356  0.77504034 -0.15891851 -0.67969822]
# MSE_train
# [8.83658398]
# MSE_test
# [9.0461034]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  3.257020655659783e-05
# [ 0.55915504 -0.21495496 -0.46065519 -0.37986359 -0.07404502  1.08081785
#  -0.64548185 -0.90665825 -0.30700216  0.97783935 -0.43523556  1.06364939
#   0.52712616  1.35284121 -1.3584474  -0.29345043 -0.61887388  0.46524691
#  -0.97761359  0.27270451  0.54574394  0.30792298 -0.58394763 -0.9885287
#  -0.50190672  0.6758975  -0.12613048  0.16288911  0.23576592  0.38139879
#   0.02318032  0.36755409 -0.37134017  0.28577364  0.21934452 -0.422691  ]
# MSE_train
# [9.2087313]
# MSE_test
# [8.37577752]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  5.2233450742668436e-05
# [ 0.91643335  0.30745044  0.87879119 -1.53429531 -0.46683547  1.68431604
#  -1.23547209  0.02592454  0.48644621 -0.31928661 -2.59979549  0.31526797
#   2.22413637  0.48552167 -0.38289234 -0.3765896  -0.74907671  0.11057411
#  -0.01123035 -1.92745592 -1.37955043  1.22937162  0.16503683 -1.274476
#  -0.9665989   0.38170111  0.25955706 -0.38124943  0.30630765  0.3461099
#  -0.01754804 -0.45015839 -0.0348944   0.75480436  0.92790431  0.38805417]
# MSE_train
# [12.784283]
# MSE_test
# [12.35848299]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  8.376776400682924e-05
# [-0.01214629 -0.83475306 -0.30035785  0.35852151 -1.08742309 -0.51693374
#   0.6152937   1.06206824  1.91440311  0.80938105 -1.14380011 -0.59787296
#   0.80950468 -1.30713761  0.61528499 -1.74079936  0.74328277  0.44613924
#   1.52821392 -0.60520813  0.5638656   0.34614531  0.79624587 -0.24828512
#   0.09902579  0.23411914  0.45159943  0.01370039  0.60514275 -0.46472947
#  -0.30845285 -1.2550238   0.27945574  0.48675021 -0.41181322 -0.46954353]
# MSE_train
# [22.43594063]
# MSE_test
# [21.99631476]
#
#
# -----------------------------
#
#
# beta from own sdg
#   0.04193896 -0.47591235  0.11401868  0.4607692  -0.27068753 -0.18585708]
# MSE_train
# [3.26415673]
# MSE_test
# [3.26218573]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.0014251026703029964
# [ 0.6680157  -0.20727736  0.43911446  0.74467714 -0.50456262 -0.66481724
#  -0.70583038  0.94430774 -1.14128506  0.2924079  -0.05481974 -1.64169686
#   1.29440194 -0.26455794 -0.01999067  0.7421441  -0.4312025   0.59718261
#  -2.33032253 -0.93183087 -0.37084478 -0.04459854  0.54671878 -0.56590824
#   0.89975428  0.15120385 -0.48292167 -0.07647336 -0.06302456 -0.00443444
#  -0.26159005  0.51118296 -0.34343119  0.37703274  0.83746773  0.21121651]
# MSE_train
# [8.49805279]
# MSE_test
# [8.97956036]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.0022854638641349886
# [ 0.77866155  1.16555677 -1.05369095  1.77701574  0.93506207  0.3731317
#  -1.68139724 -0.04547231 -0.17372236  0.75843086  0.28894763  1.59580235
#  -1.01696206  1.74950619 -0.76370598 -0.77903537  1.84247199 -1.16864425
#   0.65047355 -0.32821783 -1.02988801 -0.45796098 -0.47622014  0.15573591
#  -1.34839752 -0.09042392 -0.20787947  0.07833509  0.50290323 -1.13608356
#   0.96070326  1.64376389 -0.60416899 -1.12517654  0.6074679   0.29402985]
# MSE_train
# [25.39230277]
# MSE_test
# [24.53648283]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.003665241237079626
# [ 0.6798153   1.06105284 -1.01718292 -1.77683885 -0.81959949  1.16443562
#  -0.60602081 -0.44873295 -0.45281551  1.66297397  0.28555729 -0.1547433
#   0.29299338  0.93467384 -0.30841237 -0.20993438  1.15155189 -1.54962046
#   0.08092086 -0.02171967  0.198024    0.24460251 -0.20549466 -0.78065539
#   1.45090924  0.39011196 -1.3651752   0.19162732  0.15505112 -0.25347503
#   0.35187911 -0.95247865  0.67175046  0.64158004 -0.37999402 -0.16604778]
# MSE_train
# [17.76864459]
# MSE_test
# [17.60018157]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.0058780160722749115
# [-0.15123333 -0.42214241 -0.49196199  1.45567855 -1.82436449  0.15413267
#  -0.36008795  1.05103444 -0.00554002  0.64751963  0.54609073  0.56388802
#   0.04732009  0.01903242 -0.3535541  -0.23153298 -0.33964734  0.09786107
#   1.97376698  0.23033318 -0.21146936 -0.34209569 -0.10553329 -0.34945415
#   1.42966043 -0.11705923 -1.15992632  0.6333305   0.23339242 -0.00558549
#  -0.53540699 -1.16204922  1.40213323  0.16339277 -1.10865039  0.12638802]
# MSE_train
# [40.20051721]
# MSE_test
# [38.85411122]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.009426684551178854
# [ 0.90575429  0.23765575 -0.64852344  0.10641039 -0.51867973 -0.32899766
#  -0.20787782  0.69802275  0.52425746 -0.49286072 -0.23468859 -0.93836935
#  -0.28786716  1.8534009  -1.67757347 -1.30380712 -0.32280932  1.03638257
#   0.94973404  0.58621826  0.74260917  0.1649063   0.02513575 -0.16816017
#   0.97848702  0.18706935 -1.11746719  0.90051279  0.64477378 -0.13918831
#  -1.22282613  0.06788967  1.14336133 -0.45620435 -0.88404644 -0.11578564]
# MSE_train
# [9.62786698]
# MSE_test
# [9.22210179]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.0151177507061566
# [-0.32997119 -0.12040992 -0.54941583  1.21308457 -0.19791018  1.22601723
#  -0.91128706 -0.87110671  1.85155139  0.66522142 -0.43766819  0.42221356
#  -0.65776486 -0.61497803 -1.10060273 -0.74866716  0.93108764 -0.62991989
#   0.87325232 -0.19690452 -0.1737094  -0.0088201  -0.18212086  0.02386005
#   0.68555331  0.15426288 -0.33278771  0.44321761  0.42771906 -0.04638375
#  -0.01256514 -1.13781638  0.46340015  0.56412961 -0.42908245 -0.01258832]
# MSE_train
# [7.22767542]
# MSE_test
# [7.14845194]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.02424462017082326
# [ 0.51120638  0.32818562 -0.65558964  1.69457211  1.83290739  0.27156429
#  -0.53893689  0.61672272 -0.129795   -1.42568012 -0.84370318 -0.00750116
#  -2.06595821  0.65992146 -0.67251854 -0.78543848  1.62227313 -1.12574405
#   0.57650657  0.97814242  1.16000992  0.05503529 -0.30684721  0.25265393
#  -0.51118122  0.70152766  0.23317484  0.05144943  0.31317978 -0.89443841
#   1.1368737   1.03435011 -1.19274448 -1.05187788  0.1874032  -0.29523719]
# MSE_train
# [12.27887052]
# MSE_test
# [10.95411225]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.03888155180308085
# [-0.85025881 -0.84073794 -0.70349316  1.58818823 -1.28084821  1.78254271
#  -0.50080979 -0.47762662  0.12490102  0.89507718 -0.3771285  -1.03674717
#  -0.58592996  0.2871743   0.38474441  0.13154176  0.19026711  0.6939665
#   0.81411489 -0.95140843 -0.01307572  0.16736845  0.50742403 -1.67775773
#   0.25141638  1.73082974 -0.22427186 -0.43480122  0.12342613 -0.09930976
#  -0.07910331 -0.07039353  0.02599543 -0.22508241  0.09606954 -0.01376882]
# MSE_train
# [8.96394133]
# MSE_test
# [8.9171261]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.062355073412739125
# [ 0.38918201 -0.67781187 -1.3114641   0.17513318  1.33104112  0.16331018
#  -1.58458771  0.17744855  1.15576562  1.0018837  -0.90395321 -0.52736537
#  -0.95529395 -0.6406515  -0.05296596 -0.78844501 -0.16816695 -0.94622305
#   0.67160509  0.88275662 -1.76379033  0.25759244 -0.04832428  0.5149717
#   0.24566753 -0.2364355  -0.07510558  0.01561674  0.6089568  -0.03671107
#  -0.00310094  0.35969149  0.04057501 -0.54668262 -0.13343763  0.66248574]
# MSE_train
# [6.78899345]
# MSE_test
# [6.56903855]
#
#
# -----------------------------
#
#
# beta from own sdg
# for learning_rate =  0.1
# [ 0.94115499 -0.2657801   0.42414222  0.58292914 -0.25537303 -0.57478248
#   1.60140803  0.48603536 -0.60507087 -0.38252446 -1.26631766  0.91516321
#   0.0396458   0.21398727 -0.34252516 -0.31314888  1.92572148 -0.37807296
#   0.39658718 -0.34998811 -0.37426338  0.40405241 -0.48237869  0.45859845
#   1.15441924 -0.42499436 -0.84257618  0.36107705 -0.06387308 -0.9848133
#   0.05788484  0.35285871  0.08539857 -0.59980089  0.08239738  0.28801779]
# MSE_train
# [8.03683616]
# MSE_test
# [7.55881964]
#
#
# -----------------------------

# %%
from sklearn.linear_model import SGDRegressor

################### SDG OLS ##################
############## With sklearn ##################

nbEta = 40
Eta = np.logspace(-9, -1, nbEta)
M = 2  #size of each minibatch
n_batches = int(N/M) #number of minibatches
n_epochs = 500 #number of epochs

#############################################
best_eta = Eta[0]
best_mse = 1e10
MSE_train = [0]
MSE_test = [0]
i = 0
new_eta = []
while i < len(Eta) and MSE_train[-1] < 1e15:
    sgdreg = SGDRegressor(max_iter = 100000, penalty=None, eta0=Eta[i], learning_rate = 'constant')
    sgdreg.fit(X_train,z_train)
    print("sgdreg from scikit")
    print(sgdreg.coef_)
    print("for learning_rate = ", Eta[i])
    ztildeSDG = sgdreg.predict(X_train)
    ztestSDG = sgdreg.predict(X_test)
    MSE_train_sdg = np.mean((z_train - ztildeSDG)**2, keepdims=True )
    MSE_test_sdg = np.mean((z_test - ztestSDG)**2, keepdims=True )
    MSE_train.append(MSE_train_sdg)
    MSE_test.append(MSE_test_sdg)
    print("MSE_train")
    print(MSE_train_sdg)
    print("MSE_test")
    print(MSE_test_sdg)
    print("\n")
    print("-----------------------------")
    print("\n")
    new_eta.append(Eta[i])
    if MSE_test_sdg < best_mse:
        best_eta = Eta[i]
        best_mse = MSE_test_sdg
        zpred = sgdreg.predict(X)
    i +=1



plt.plot(new_eta[:-1], MSE_train[1:-1], label = "MSE_train")
plt.plot(new_eta[:-1], MSE_test[1:-1], label = "MSE_test")
plt.xscale('log')
plt.xlabel('learning_rate')
plt.ylabel('MSE')
plt.title("SDG OLS")
plt.legend()

plotFunction(x_mesh, y_mesh, z, "Plot of our data")
title = "plot of regression with SDG with learning rate =" + str(best_eta)
plotFunction(x_mesh, y_mesh, zpred.reshape(len(x), len(x)),title)


plt.show()
# Out:
# sgdreg from scikit
# [ 1.94111011e-05 -1.52425570e-07  1.49279195e-07  1.93664983e-05
#   7.40421669e-08  1.92694377e-05 -1.64555248e-07  1.17980776e-07
#  -3.61648401e-07  4.05488753e-07  3.49547571e-05  1.34659261e-08
#   1.89700694e-05  1.25602008e-07  3.44998799e-05 -2.92319439e-07
#   1.16908705e-07 -6.24542714e-07  5.04525612e-07 -6.97508362e-07
#   1.15795775e-06  7.52690112e-05  7.17618284e-08  3.42286288e-05
#  -7.07425852e-08  3.37628712e-05  2.89362537e-07  7.34745042e-05
#  -5.34195330e-07  9.89532858e-08 -1.26811975e-06  9.43092022e-07
#  -1.15871516e-06  1.58197812e-06 -1.63617259e-06  3.20333396e-06]
# for learning_rate =  1e-09
# MSE_train
# [0.25553004]
